# %%
o1 person
o10 clothes
o16 floor
o37 hands
o38 hair

# %%
import json
import pickle
import random
import pandas as pd
import os
import math
import grammar
import shutil
import subprocess

# %%
#infile = open('../data/test_videos_stsg.pkl', 'rb')
infile = open('../data/testing_camera_ready_stsgs.pkl', 'rb')
test_stsgs = pickle.load(infile)
infile.close()

#infile = open('../data/test_videos_stsg.pkl', 'rb')
infile = open('../data/training_camera_ready_stsgs.pkl', 'rb')
train_stsgs = pickle.load(infile)
infile.close()

# %%
def snip(arr):
    for i in range(len(arr)): 
        arr[i] = arr[i][:-1]
def readLines(path):
    file = open(path)
    info = file.read()
    file.close()
    
    return info

def loadPickle(path):
    file = open(path, 'rb')
    info = pickle.load(file)
    file.close()
    return info

ENG = loadPickle('../data/eng.pkl')
PP = loadPickle('../data/pres_part.pkl')
IDX = loadPickle('../data/idx.pkl')

# %%
objs = readLines('../data/object_classes.txt')
objs = objs.split('\n')[:-2]


objs
# Out:
# ['o1 person',
#  'o2 bag',
#  'o3 bed',
#  'o4 blanket',
#  'o5 book',
#  'o6 box',
#  'o7 broom',
#  'o8 chair',
#  'o9 closet',
#  'o10 clothes',
#  'o11 cup',
#  'o12 dish',
#  'o13 door',
#  'o14 doorknob',
#  'o15 doorway',
#  'o16 floor',
#  'o17 food',
#  'o18 groceries',
#  'o19 laptop',
#  'o20 light',
#  'o21 medicine',
#  'o22 mirror',
#  'o23 paper',
#  'o24 phone',
#  'o25 picture',
#  'o26 pillow',
#  'o27 refrigerator',
#  'o28 sandwich',
#  'o29 shelf',
#  'o30 shoe',
#  'o31 sofa',
#  'o32 table',
#  'o33 television',
#  'o34 towel',
#  'o35 vacuum',
#  'o36 window',
#  'o37 hands',
#  'o38 hair']

# %%
objs = readLines('../data/object_classes.txt')

objs = objs.split('\n')[:-2]

objs = [i.split(' ')[1] for i in objs]

# likely to be in there
objs.remove('person')
objs.remove('clothes')
objs.remove('floor')
objs.remove('hands')
objs.remove('hair')
objs.remove('shoe')

# totally removed 
objs.remove('sofa')
objs.remove('towel')
objs.remove('cup')
objs.remove('sandwich')
objs.remove('groceries')
objs.remove('book')
objs.remove('shelf')

objs
# Out:
# ['bag',
#  'bed',
#  'blanket',
#  'box',
#  'broom',
#  'chair',
#  'closet',
#  'dish',
#  'door',
#  'doorknob',
#  'doorway',
#  'food',
#  'laptop',
#  'light',
#  'medicine',
#  'mirror',
#  'paper',
#  'phone',
#  'picture',
#  'pillow',
#  'refrigerator',
#  'table',
#  'television',
#  'vacuum',
#  'window']

# %%
len(objs)
# Out:
# 25

# %%
objs = [['bag', 'bed', 'blanket', 'box', 'broom'],
      ['chair', 'closet', 'dish', 'door', 'doorknob'],
      ['doorway', 'food', 'laptop', 'light', 'medicine'],
      ['mirror', 'paper', 'phone', 'picture', 'pillow'],
      ['refrigerator', 'table', 'television', 'vacuum', 'window']]

total_

# %%
objNoExist = []

objNoExist

# %%
objNoExist = [1 != 1] * 25

# %%
objNoExist
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %% [markdown]
# # Get lists of video_ids

# %%
def getSTSGS(group):
    if group == 'train': 
        return train_stsgs
    elif group == 'test':
        return test_stsgs
    else:
        print('invalid group', group)
        return

def save_urls(group, start, stop, video_folder):
    stsgs = list(getSTSGS(group).keys())
    url_path = "https://visualgenome.org/hits/agqa_videos?filename="
    src_path = '../Charades_v1_480/%s.mp4'
    dest_path = '../AMT/easyturk/easyturk/videos/%s/%s.mp4'
    
    video_ids = stsgs[start:stop]
    amt_input = []
    
    for v in video_ids:
        # add video url path
        url = url_path + v
        amt_input.append({'url': url})
        
        # get videos to upload to scene graphs
        src_file = src_path % v
        dest_file = dest_path % (video_folder, v)
        shutil.copyfile(src_file, dest_file)
        
    with open('../AMT/easyturk/easyturk/data/object_dataset/%s-%s.txt' % (start, stop), 'w+') as f:
        json.dump(amt_input, f)
        
    return amt_input

    


amt_input = save_urls('train', 0, 100, '11-12')

# %%
amt_input
# Out:
# [{'url': 'https://visualgenome.org/hits/agqa_videos?filename=46GP8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=N11GT'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=KRF68'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=MJO7C'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S6MPZ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=7HVU8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=MCQO5'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=VPIYF'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=JSUF4'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=8WJIR'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=INQNU'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=LI6LV'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=MGCM8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=I8QJN'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=XC9EY'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=DOQ9Y'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=RK9II'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=QGQGZ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=5S1WQ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=CUCBN'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=SX0HE'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=72JYK'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=BDFDE'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=H6N4Z'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=OBTP8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=4021N'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=ZSHWE'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=SFDTP'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=Q5EPP'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=SK6FW'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=VHIG7'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=0R6K4'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=PSPMA'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=MD41D'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=SDXZ8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S673O'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=U79C9'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=N915C'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=FXRMG'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=P68QV'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=78XZ9'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=0VOQC'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=E6Q95'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=G99VH'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=DWHPO'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=H603E'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=CBXVQ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=PN4MI'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=VJ2QS'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=FI1LR'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=AY08E'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=7XNAI'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=IST7I'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=OI3BC'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=F4BJJ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=83654'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=0G0YF'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=0R5GS'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=PVB4S'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=N2OCX'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=Q5GVZ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=R7107'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=UMOE4'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=QLWQ4'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S9P0W'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=U1DTW'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=R6CIX'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=2PREF'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=57J92'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=R2DA8'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=VCU4P'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=U3OJV'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=T1CQE'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=FPNT1'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=3ZKDY'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=3MAY9'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=0TQZQ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=G70A2'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=R00LO'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=CMD0M'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=2WGSN'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=KV99H'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=EDVAM'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=R1S1Z'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=FDYQZ'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=V3DJ5'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=9GMHF'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=G6MYM'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=7HZHM'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=XOMJ4'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=L2ZZB'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=5ACD3'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=UAT1F'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=MZOPX'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=VLE11'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S67WR'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=SYMIR'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=U3VOM'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=Q01UB'},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S72J9'}]

# %% [markdown]
# # TODO
# - would be nice for some instructions on what means what
#
# total_replacement = {
#     'sofa': 'bed',
#     'sofa/couch': 'bed',
#     'towel': 'blanket',
#     # NOTE: CHANGE DEF 'dish': 'cup',
#     'cup': 'dish',
#     'sandwich': 'food',
#     'groceries': 'food',
#     # NOTE: CHANGE DEF 'paper': 'book',
#     'book': 'paper',
#     'shelf': 'table'
# }

# %% [markdown]
# # Process results

# %%
def loadResults(paths):
    results = {}
    for p in paths:
        with open('../AMT/easyturk/easyturk/results/%s.txt' % p, 'rb') as infile:
            new_results = pickle.load(infile)
        results.update(new_results)
        
    dicts = []
    zipped = {}
    by_obj = []
    for i in results:
        for j in results[i]:
            worker = j['worker_id']
            for k in j['output']:
                k['worker'] = worker
            #dicts += j['output']
            
            for d in j['output']:
                if 'feedback' in d:
                    print(d['feedback'])
                exists = d['objNoExist'][0]
                objs = d['objs']
                
                zipped[d['url'][-5:]] = list(zip(objs, exists))
                
                new_d = {'url': d['url']}
                for idx in range(len(exists)):
                    new_d[objs[idx]] = exists[idx]
                
                dicts.append(new_d)
            
    df = pd.DataFrame(dicts)
    
    return df, dicts, zipped


# 'test_objects_me' -- the ones I did
df, dicts, zipped = loadResults(['test_objects_firstone'])
# Out:
# {'30EV7DWJTVUAJNWJPU4MR41NDU7Y6W': [{'assignment_id': '3P4RDNWND65332UFVYH9348WFELIJ0', 'hit_id': '30EV7DWJTVUAJNWJPU4MR41NDU7Y6W', 'worker_id': 'A2T11H7YI7QPGD', 'output': [{'url': 'https://visualgenome.org/hits/agqa_videos?filename=JSUF4', 'objNoExist': [[False, True, False, False, True, True, False, False, True, True, True, False, False, False, False, True, False, False, False, False, False, False, False, False, False]], 'objs': ['bag', 'bed', 'blanket', 'box', 'broom', 'chair', 'closet', 'dish', 'door', 'doorknob', 'doorway', 'food', 'laptop', 'light', 'medicine', 'mirror', 'paper', 'phone', 'picture', 'pillow', 'refrigerator', 'table', 'television', 'vacuum', 'window'], 'feedback': ['']}], 'submit_time': datetime.datetime(2021, 11, 12, 18, 18, 54, tzinfo=tzlocal())}]}
# ['']

# %%
df
# Out:
#                                                  url    bag   bed  blanket  \
# 0  https://visualgenome.org/hits/agqa_videos?file...  False  True    False
#
#      box  broom  chair  closet   dish  door  ...  mirror  paper  phone  \
# 0  False   True   True   False  False  True  ...    True  False  False
#
#    picture  pillow  refrigerator  table  television  vacuum  window
# 0    False   False         False  False       False   False   False
#
# [1 rows x 26 columns]

# %%
zipped
# Out:
# {'JSUF4': [('bag', False),
#   ('bed', True),
#   ('blanket', False),
#   ('box', False),
#   ('broom', True),
#   ('chair', True),
#   ('closet', False),
#   ('dish', False),
#   ('door', True),
#   ('doorknob', True),
#   ('doorway', True),
#   ('food', False),
#   ('laptop', False),
#   ('light', False),
#   ('medicine', False),
#   ('mirror', True),
#   ('paper', False),
#   ('phone', False),
#   ('picture', False),
#   ('pillow', False),
#   ('refrigerator', False),
#   ('table', False),
#   ('television', False),
#   ('vacuum', False),
#   ('window', False)]}

# %%
dicts
# Out:
# [{'url': 'https://visualgenome.org/hits/agqa_videos?filename=H46LQ',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': False,
#   'closet': True,
#   'dish': False,
#   'door': True,
#   'doorknob': True,
#   'doorway': True,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': False,
#   'refrigerator': False,
#   'table': False,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=ZJ37U',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': False,
#   'closet': True,
#   'dish': True,
#   'door': False,
#   'doorknob': False,
#   'doorway': False,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': False,
#   'vacuum': True,
#   'window': False},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=KQ6XW',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': False,
#   'chair': False,
#   'closet': False,
#   'dish': False,
#   'door': True,
#   'doorknob': True,
#   'doorway': True,
#   'food': True,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=ZI1GC',
#   'bag': False,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': False,
#   'closet': False,
#   'dish': True,
#   'door': False,
#   'doorknob': False,
#   'doorway': False,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': False,
#   'phone': True,
#   'picture': False,
#   'pillow': True,
#   'refrigerator': True,
#   'table': False,
#   'television': True,
#   'vacuum': False,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=S5KQ1',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': False,
#   'broom': False,
#   'chair': False,
#   'closet': False,
#   'dish': True,
#   'door': False,
#   'doorknob': True,
#   'doorway': False,
#   'food': True,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': True,
#   'vacuum': True,
#   'window': False},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=3OLX3',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': True,
#   'closet': False,
#   'dish': False,
#   'door': True,
#   'doorknob': True,
#   'doorway': True,
#   'food': True,
#   'laptop': True,
#   'light': True,
#   'medicine': False,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': False,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=5TYXL',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': False,
#   'broom': False,
#   'chair': True,
#   'closet': True,
#   'dish': False,
#   'door': True,
#   'doorknob': True,
#   'doorway': True,
#   'food': True,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=7E2AJ',
#   'bag': True,
#   'bed': True,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': True,
#   'closet': True,
#   'dish': True,
#   'door': True,
#   'doorknob': True,
#   'doorway': True,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=W0XPU',
#   'bag': True,
#   'bed': False,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': True,
#   'closet': False,
#   'dish': True,
#   'door': False,
#   'doorknob': False,
#   'doorway': False,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': True,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': True,
#   'refrigerator': True,
#   'table': True,
#   'television': True,
#   'vacuum': True,
#   'window': True},
#  {'url': 'https://visualgenome.org/hits/agqa_videos?filename=K8OB6',
#   'bag': True,
#   'bed': False,
#   'blanket': True,
#   'box': True,
#   'broom': True,
#   'chair': True,
#   'closet': False,
#   'dish': True,
#   'door': False,
#   'doorknob': False,
#   'doorway': False,
#   'food': False,
#   'laptop': True,
#   'light': True,
#   'medicine': True,
#   'mirror': False,
#   'paper': True,
#   'phone': True,
#   'picture': True,
#   'pillow': False,
#   'refrigerator': True,
#   'table': False,
#   'television': True,
#   'vacuum': True,
#   'window': False}]

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined
